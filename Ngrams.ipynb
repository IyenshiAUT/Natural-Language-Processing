# %%
import pandas as pd

messages = pd.read_csv('smsspamcollection/SMSSpamCollection', sep='\t', names = ["label","message"])
messages
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import nltk
import re

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()

# %%
corpus=[]
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)
    corpus.append(review)

# %%
from sklearn.feature_extraction.text import CountVectorizer
# for Binary Bag  of Words
cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(3,3))
X = cv.fit_transform(corpus).toarray()
cv.vocabulary_
# Out:
# {'free entri wkli': 671,
#  'comp win fa': 357,
#  'fa cup final': 577,
#  'final tkt st': 614,
#  'tkt st may': 2116,
#  'st may text': 1997,
#  'fa receiv entri': 578,
#  'receiv entri question': 1618,
#  'std txt rate': 2019,
#  'txt rate appli': 2244,
#  'per request mell': 1480,
#  'request mell mell': 1673,
#  'mell mell oru': 1255,
#  'mell oru minnaminungint': 1256,
#  'oru minnaminungint nurungu': 1433,
#  'minnaminungint nurungu vettam': 1274,
#  'nurungu vettam set': 1378,
#  'vettam set callertun': 2381,
#  'set callertun caller': 1840,
#  'callertun caller press': 156,
#  'caller press copi': 153,
#  'press copi friend': 1576,
#  'copi friend callertun': 404,
#  'winner valu network': 2456,
#  'valu network custom': 2379,
#  'select receivea prize': 1784,
#  'receivea prize reward': 1622,
#  'reward claim call': 1684,
#  'claim call claim': 262,
#  'call claim code': 91,
#  'claim code kl': 266,
#  'code kl valid': 302,
#  'kl valid hour': 1091,
#  'entitl updat latest': 542,
#  'updat latest colour': 2294,
#  'latest colour mobil': 1150,
#  'colour mobil camera': 324,
#  'camera free call': 164,
#  'free call mobil': 662,
#  'call mobil updat': 113,
#  'mobil updat co': 1296,
#  'updat co free': 2292,
#  'six chanc win': 1897,
#  'chanc win cash': 224,
#  'cash pound txt': 206,
#  'txt csh send': 2226,
#  'send cost day': 1794,
#  'cost day day': 406,
#  'tsandc appli repli': 2205,
#  'repli hl info': 1654,
#  'urgent week free': 2364,
#  'free membership prize': 675,
#  'jackpot txt word': 1047,
#  'txt word claim': 2251,
#  'claim www dbuk': 283,
#  'lccltd pobox ldnw': 1161,
#  'pobox ldnw rw': 1552,
#  'get worri know': 789,
#  'tri call repli': 2185,
#  'call repli sm': 133,
#  'call deliveri tomorrow': 95,
#  'lt gt inch': 1206,
#  'call messag miss': 105,
#  'messag miss call': 1259,
#  'like lt gt': 1171,
#  'lt url gt': 1219,
#  'congrat year special': 378,
#  'year special cinema': 2497,
#  'special cinema pass': 1975,
#  'cinema pass call': 260,
#  'pass call suprman': 1452,
#  'call suprman matrix': 140,
#  'suprman matrix starwar': 2042,
#  'matrix starwar etc': 1246,
#  'starwar etc free': 2015,
#  'etc free bx': 547,
#  'free bx ip': 661,
#  'bx ip pm': 87,
#  'ip pm dont': 1032,
#  'pm dont miss': 1541,
#  'sorri call later': 1959,
#  'call later meet': 104,
#  'part check iq': 1444,
#  'valu custom pleas': 2378,
#  'custom pleas advis': 453,
#  'pleas advis follow': 1524,
#  'advis follow recent': 6,
#  'follow recent review': 645,
#  'recent review mob': 1623,
#  'review mob award': 1683,
#  'mob award bonu': 1280,
#  'award bonu prize': 46,
#  'bonu prize call': 73,
#  'today song dedic': 2130,
#  'song dedic day': 1949,
#  'dedic day song': 493,
#  'song dedic send': 1950,
#  'dedic send ur': 494,
#  'send ur valuabl': 1815,
#  'ur valuabl frnd': 2348,
#  'frnd first rpli': 722,
#  'urgent ur award': 2362,
#  'ur award complimentari': 2301,
#  'complimentari trip eurodisinc': 365,
#  'trip eurodisinc trav': 2194,
#  'trav aco entri': 2182,
#  'claim txt di': 277,
#  'txt di morefrmmob': 2227,
#  'shracomorsglsuplt ls aj': 1872,
#  'that cool gentleman': 2088,
#  'cool gentleman treat': 403,
#  'gentleman treat digniti': 759,
#  'treat digniti respect': 2184,
#  'later network urgnt': 1147,
#  'smile pleasur smile': 1927,
#  'smile pain smile': 1926,
#  'pain smile troubl': 1439,
#  'smile troubl pour': 1932,
#  'troubl pour like': 2196,
#  'smile sum hurt': 1930,
#  'smile becoz someon': 1923,
#  'someon still love': 1945,
#  'pleas call custom': 1526,
#  'call custom servic': 94,
#  'custom servic repres': 455,
#  'servic repres pm': 1836,
#  'repres pm guarante': 1671,
#  'pm guarante cash': 1542,
#  'guarante cash prize': 931,
#  'free rington wait': 685,
#  'rington wait collect': 1698,
#  'collect simpli text': 318,
#  'simpli text password': 1885,
#  'password mix verifi': 1455,
#  'get usher britney': 787,
#  'fml po box': 643,
#  'po box mk': 1547,
#  'gent tri contact': 758,
#  'tri contact last': 2186,
#  'contact last weekend': 389,
#  'last weekend draw': 1142,
#  'weekend draw show': 2423,
#  'draw show prize': 523,
#  'show prize guarante': 1869,
#  'prize guarante call': 1586,
#  'guarante call claim': 928,
#  'claim code valid': 268,
#  'code valid hr': 304,
#  'valid hr ppm': 2377,
#  'enter cabin pa': 539,
#  'cabin pa said': 88,
#  'pa said happi': 1436,
#  'said happi day': 1724,
#  'happi day boss': 949,
#  'day boss felt': 465,
#  'boss felt special': 76,
#  'felt special askd': 603,
#  'special askd lunch': 1972,
#  'askd lunch lunch': 35,
#  'lunch lunch invit': 1223,
#  'lunch invit apart': 1222,
#  'invit apart went': 1028,
#  'winner special select': 2455,
#  'special select receiv': 1979,
#  'holiday flight inc': 978,
#  'flight inc speak': 640,
#  'inc speak live': 1009,
#  'speak live oper': 1971,
#  'live oper claim': 1177,
#  'oper claim min': 1411,
#  'privat account statement': 1581,
#  'account statement show': 4,
#  'statement show unredeem': 2017,
#  'show unredeem bonu': 1871,
#  'unredeem bonu point': 2283,
#  'bonu point claim': 72,
#  'point claim call': 1560,
#  'claim call identifi': 264,
#  'call identifi code': 98,
#  'identifi code expir': 998,
#  'urgent mobil award': 2356,
#  'mobil award bonu': 1284,
#  'award bonu caller': 45,
#  'bonu caller prize': 71,
#  'caller prize final': 154,
#  'today voda number': 2136,
#  'voda number end': 2388,
#  'number end select': 1375,
#  'end select receiv': 537,
#  'select receiv award': 1780,
#  'receiv award match': 1613,
#  'award match pleas': 51,
#  'match pleas call': 1243,
#  'pleas call quot': 1529,
#  'call quot claim': 130,
#  'quot claim code': 1597,
#  'claim code standard': 267,
#  'code standard rate': 303,
#  'standard rate app': 2005,
#  'wat time finish': 2408,
#  'time give call': 2099,
#  'sunshin quiz wkli': 2041,
#  'quiz wkli win': 1596,
#  'wkli win top': 2464,
#  'win top soni': 2452,
#  'top soni dvd': 2171,
#  'soni dvd player': 1952,
#  'dvd player know': 528,
#  'player know countri': 1522,
#  'know countri algarv': 1094,
#  'countri algarv txt': 418,
#  'txt ansr sp': 2217,
#  'ansr sp tyron': 23,
#  'get laid tonight': 773,
#  'laid tonight want': 1121,
#  'tonight want real': 2166,
#  'want real dog': 2406,
#  'real dog locat': 1608,
#  'dog locat sent': 515,
#  'locat sent direct': 1179,
#  'sent direct ur': 1820,
#  'ur mob join': 2332,
#  'join uk largest': 1066,
#  'uk largest dog': 2265,
#  'largest dog network': 1136,
#  'check room befor': 249,
#  'room befor activ': 1701,
#  'sir wait mail': 1892,
#  'per msg repli': 1478,
#  'repli stop end': 1663,
#  'select receiv cash': 1781,
#  'receiv cash holiday': 1617,
#  'cash holiday flight': 202,
#  'invit friend repli': 1029,
#  'friend repli ye': 710,
#  'repli ye see': 1668,
#  'ye see www': 2496,
#  'see www sm': 1776,
#  'www sm ac': 2486,
#  'stop send stop': 2027,
#  'send stop frnd': 1807,
#  'urgent tri contact': 2361,
#  'complet form clark': 362,
#  'form clark also': 654,
#  'clark also utter': 285,
#  'time come later': 2096,
#  'smoke lt gt': 1933,
#  'lt gt worth': 1215,
#  'hi spoke maneesha': 967,
#  'spoke maneesha like': 1988,
#  'maneesha like know': 1237,
#  'like know satisfi': 1170,
#  'know satisfi experi': 1104,
#  'satisfi experi repli': 1733,
#  'experi repli toll': 569,
#  'repli toll free': 1665,
#  'toll free ye': 2142,
#  'servic repres freephon': 1835,
#  'repres freephon pm': 1669,
#  'freephon pm guarante': 701,
#  'settl new school': 1841,
#  'school year wishin': 1751,
#  'gud mrng dear': 935,
#  'mrng dear hav': 1309,
#  'dear hav nice': 478,
#  'hav nice day': 953,
#  'got person stori': 878,
#  'sent lt gt': 1822,
#  'lt gt buck': 1202,
#  'refil success inr': 1633,
#  'inr lt decim': 1022,
#  'lt decim gt': 1200,
#  'gt keralacircl prepaid': 912,
#  'keralacircl prepaid account': 1082,
#  'rs lt decim': 1707,
#  'decim gt transact': 491,
#  'gt transact id': 923,
#  'transact id kr': 2179,
#  'kr lt gt': 1115,
#  'shoot big load': 1856,
#  'sen got select': 1790,
#  'got select mean': 880,
#  'select mean good': 1779,
#  'take ur time': 2050,
#  'new mobil must': 1348,
#  'mobil must go': 1293,
#  'must go txt': 1328,
#  'go txt nokia': 839,
#  'txt nokia collect': 2235,
#  'nokia collect today': 1361,
#  'collect today www': 320,
#  'today www tc': 2138,
#  'www tc biz': 2487,
#  'tc biz optout': 2051,
#  'biz optout gbp': 66,
#  'optout gbp mtmsg': 1416,
#  'dear good morn': 475,
#  'sorri batteri die': 1958,
#  'tv alway avail': 2209,
#  'new theori argument': 1351,
#  'theori argument win': 2091,
#  'argument win situat': 28,
#  'win situat lose': 2449,
#  'situat lose person': 1896,
#  'lose person dont': 1188,
#  'person dont argu': 1486,
#  'dont argu ur': 516,
#  'argu ur friend': 27,
#  'ur friend kick': 2314,
#  'friend kick amp': 708,
#  'kick amp say': 1084,
#  'amp say alway': 16,
#  'say alway correct': 1742,
#  'secret admir look': 1763,
#  'admir look make': 5,
#  'look make contact': 1183,
#  'make contact find': 1231,
#  'contact find reveal': 388,
#  'find reveal think': 621,
#  'reveal think ur': 1681,
#  'think ur special': 2092,
#  'ur special call': 2342,
#  'congratul ur award': 380,
#  'ur award cd': 2299,
#  'award cd voucher': 48,
#  'cd voucher gift': 216,
#  'voucher gift guarante': 2396,
#  'gift guarante free': 794,
#  'guarante free entri': 932,
#  'entri wkli draw': 546,
#  'wkli draw txt': 2463,
#  'draw txt music': 525,
#  'txt music tnc': 2232,
#  'music tnc www': 1327,
#  'tnc www ldew': 2119,
#  'www ldew com': 2483,
#  'ldew com win': 1163,
#  'com win ppmx': 337,
#  'win ppmx age': 2448,
#  'deeraj deepak min': 497,
#  'deepak min hold': 496,
#  'wen ur lovabl': 2430,
#  'ur lovabl bcum': 2323,
#  'lovabl bcum angri': 1190,
#  'bcum angri wid': 59,
#  'angri wid dnt': 21,
#  'wid dnt take': 2437,
#  'dnt take serious': 514,
#  'take serious coz': 2049,
#  'serious coz angri': 1826,
#  'coz angri childish': 422,
#  'angri childish true': 20,
#  'childish true way': 252,
#  'true way show': 2200,
#  'way show deep': 2414,
#  'show deep affect': 1868,
#  'deep affect care': 495,
#  'affect care luv': 7,
#  'care luv kettoda': 186,
#  'luv kettoda manda': 1224,
#  'kettoda manda nice': 1083,
#  'manda nice day': 1236,
#  'nice day da': 1357,
#  'tri contact repli': 2189,
#  'contact repli offer': 394,
#  'repli offer video': 1658,
#  'video handset anytim': 2384,
#  'handset anytim network': 945,
#  'anytim network min': 25,
#  'network min unlimit': 1345,
#  'min unlimit text': 1271,
#  'unlimit text camcord': 2280,
#  'text camcord repli': 2066,
#  'camcord repli call': 159,
#  'dun disturb liao': 527,
#  'unsubscrib text stop': 2289,
#  'choos top qualiti': 258,
#  'night end anoth': 1358,
#  'end anoth day': 536,
#  'anoth day morn': 22,
#  'day morn come': 469,
#  'morn come special': 1305,
#  'come special way': 349,
#  'special way may': 1981,
#  'way may smile': 2413,
#  'may smile like': 1250,
#  'smile like sunni': 1925,
#  'like sunni ray': 1172,
#  'sunni ray leav': 2040,
#  'ray leav worri': 1601,
#  'leav worri blue': 1165,
#  'worri blue blue': 2475,
#  'blue blue bay': 69,
#  'hmv bonu special': 970,
#  'bonu special pound': 74,
#  'special pound genuin': 1978,
#  'pound genuin hmv': 1570,
#  'genuin hmv voucher': 761,
#  'hmv voucher answer': 972,
#  'voucher answer easi': 2391,
#  'answer easi question': 24,
#  'easi question play': 531,
#  'question play send': 1595,
#  'play send hmv': 1521,
#  'send hmv info': 1800,
#  'hmv info www': 971,
#  'info www percent': 1017,
#  'www percent real': 2484,
#  'percent real com': 1483,
#  'peopl life world': 1467,
#  'friend call world': 705,
#  'call world ge': 148,
#  'custom may claim': 452,
#  'may claim free': 1249,
#  'claim free camera': 271,
#  'free camera phone': 666,
#  'camera phone upgrad': 170,
#  'loyalti call offer': 1198,
#  'call offer end': 121,
#  'cri end life': 431,
#  'plz keep one': 1536,
#  'keep one rose': 1077,
#  'one rose grave': 1406,
#  'rose grave say': 1702,
#  'grave say stupid': 890,
#  'say stupid miss': 1749,
#  'cant pick phone': 177,
#  'pick phone right': 1509,
#  'phone right pl': 1507,
#  'right pl send': 1688,
#  'pl send messag': 1516,
#  'coffe run tomo': 305,
#  'run tomo believ': 1715,
#  'tomo believ time': 2143,
#  'time week alreadi': 2111,
#  'today accept day': 2122,
#  'accept day accept': 2,
#  'day accept brother': 464,
#  'accept brother sister': 1,
#  'brother sister lover': 82,
#  'sister lover dear': 1893,
#  'lover dear best': 1197,
#  'dear best clo': 473,
#  'best clo lvblefrnd': 63,
#  'clo lvblefrnd jstfrnd': 287,
#  'lvblefrnd jstfrnd cutefrnd': 1225,
#  'jstfrnd cutefrnd lifpartnr': 1073,
#  'cutefrnd lifpartnr belovd': 457,
#  'lifpartnr belovd swtheart': 1167,
#  'belovd swtheart bstfrnd': 62,
#  'swtheart bstfrnd rpli': 2046,
#  'bstfrnd rpli mean': 83,
#  'rpli mean enemi': 1705,
#  'decemb mobil mth': 488,
#  'mobil mth entitl': 1291,
#  'mth entitl updat': 1317,
#  'latest colour camera': 1149,
#  'colour camera mobil': 322,
#  'camera mobil free': 165,
#  'mobil free call': 1289,
#  'babe love ya': 56,
#  'germani penc per': 763,
#  'penc per minut': 1464,
#  'per minut call': 1476,
#  'fix line via': 635,
#  'special win quiz': 1982,
#  'partner trip lifetim': 1450,
#  'trip lifetim send': 2195,
#  'send go msg': 1799,
#  'go msg rcvd': 830,
#  'gudnit tc practic': 938,
#  'today sorri day': 2131,
#  'sorri day ever': 1961,
#  'ever misbehav hurt': 552,
#  'plz plz slap': 1538,
#  'plz slap urself': 1539,
#  'slap urself bcoz': 1905,
#  'urself bcoz ur': 2367,
#  'ur fault basic': 2310,
#  'fault basic good': 593,
#  'jay tri figur': 1052,
#  'tri figur much': 2191,
#  'lt gt ish': 1207,
#  'ur cash balanc': 2304,
#  'cash balanc current': 198,
#  'balanc current pound': 57,
#  'current pound maxim': 450,
#  'pound maxim ur': 1571,
#  'maxim ur cash': 1248,
#  'ur cash send': 2305,
#  'cash send cash': 208,
#  'send cash msg': 1792,
#  'cash msg cc': 204,
#  'cc hg suit': 212,
#  'hg suit land': 964,
#  'suit land row': 2036,
#  'land row hl': 1125,
#  'latest motorola sonyericsson': 1152,
#  'motorola sonyericsson nokia': 1307,
#  'sonyericsson nokia free': 1955,
#  'doubl min txt': 521,
#  'min txt orang': 1270,
#  'txt orang call': 2238,
#  'orang call mobileupd': 1421,
#  'call mobileupd call': 115,
#  'mobileupd call optout': 1299,
#  'geeee miss alreadi': 757,
#  'next lt gt': 1356,
#  'lt gt min': 1210,
#  'thank rington order': 2086,
#  'rington order refer': 1695,
#  'txt month free': 2231,
#  'free bluetooth orang': 660,
#  'orang avail soni': 1419,
#  'soni nokia motorola': 1953,
#  'phone call mobileupd': 1497,
#  'call optout dx': 123,
#  'mth half price': 1318,
#  'half price orang': 943,
#  'price orang line': 1580,
#  'orang line rental': 1424,
#  'line rental latest': 1174,
#  'rental latest camera': 1645,
#  'latest camera phone': 1148,
#  'camera phone free': 168,
#  'phone free phone': 1503,
#  'free phone mth': 682,
#  'phone mth call': 1506,
#  'mth call mobilesdirect': 1316,
#  'call mobilesdirect free': 114,
#  'mobilesdirect free updat': 1298,
#  'free updat stoptxt': 697,
#  'good even sir': 857,
#  'great loxahatche xma': 896,
#  'sender name miss': 1817,
#  'sent date miss': 1819,
#  'that everyth miss': 2089,
#  'everyth miss sent': 559,
#  'sent via fullonsm': 1824,
#  'via fullonsm com': 2382,
#  'go yan jiu': 844,
#  'free entri weekli': 670,
#  'txttowin co uk': 2258,
#  'send logo ur': 1801,
#  'ur lover name': 2325,
#  'join heart txt': 1063,
#  'txt love name': 2230,
#  'someon contact date': 1938,
#  'contact date servic': 387,
#  'date servic enter': 462,
#  'servic enter phone': 1832,
#  'phone fanci find': 1500,
#  'fanci find call': 583,
#  'find call landlin': 617,
#  'call landlin pobox': 103,
#  'landlin pobox tf': 1134,
#  'urgent mobil number': 2357,
#  'mobil number award': 1294,
#  'number award prize': 1374,
#  'award prize guarante': 53,
#  'guarante call land': 929,
#  'call land line': 100,
#  'land line claim': 1122,
#  'line claim valid': 1173,
#  'claim valid hr': 281,
#  'wnt buy bmw': 2465,
#  'buy bmw car': 86,
#  'bmw car urgent': 70,
#  'car urgent vri': 179,
#  'urgent vri urgent': 2363,
#  'vri urgent hv': 2400,
#  'urgent hv shortag': 2353,
#  'hv shortag lt': 994,
#  'shortag lt gt': 1865,
#  'lt gt lac': 1208,
#  'gt lac sourc': 913,
#  'lac sourc arng': 1119,
#  'sourc arng di': 1967,
#  'arng di amt': 29,
#  'di amt lt': 505,
#  'amt lt gt': 19,
#  'gt lac that': 914,
#  'lac that prob': 1120,
#  'watch tv lor': 2412,
#  'congrat nokia video': 377,
#  'video camera phone': 2383,
#  'camera phone call': 167,
#  'phone call call': 1496,
#  'cost ppm ave': 409,
#  'call min vari': 107,
#  'close post bcm': 291,
#  'ldn wc xx': 1164,
#  'lt gt th': 1213,
#  'lt gt dollar': 1203,
#  'pay lt gt': 1458,
#  'lt gt lt': 1209,
#  'gt lt gt': 916,
#  'great bhaji told': 893,
#  'told kalli best': 2141,
#  'kalli best cricket': 1075,
#  'cricket sachin world': 432,
#  'sachin world tough': 1716,
#  'love jen xxx': 1196,
#  'loan purpos homeown': 1178,
#  'purpos homeown tenant': 1591,
#  'homeown tenant welcom': 983,
#  'tenant welcom previous': 2059,
#  'welcom previous refus': 2427,
#  'previous refus still': 1578,
#  'refus still help': 1634,
#  'still help call': 2022,
#  'help call free': 962,
#  'call free text': 96,
#  'free text back': 693,
#  'text back help': 2063,
#  'orang custom may': 1422,
#  'upgrad loyalti call': 2295,
#  'lt gt time': 1214,
#  'gt time per': 922,
#  'time per night': 2104,
#  'final notic collect': 613,
#  'collect tenerif holiday': 319,
#  'tenerif holiday cash': 2060,
#  'cash award call': 196,
#  'landlin tc sae': 1135,
#  'sae box cw': 1718,
#  'box cw wx': 78,
#  'cw wx ppm': 458,
#  'transfer lt gt': 2181,
#  'account lt gt': 3,
#  'send account detail': 1791,
#  'love aathi love': 1192,
#  'aathi love lot': 0,
#  'free messag activ': 676,
#  'free text messag': 695,
#  'repli messag word': 1657,
#  'free term condit': 692,
#  'condit visit www': 371,
#  'sorri meet call': 1962,
#  'meet call later': 1252,
#  'fight world easi': 605,
#  'world easi either': 2472,
#  'easi either win': 530,
#  'either win lose': 535,
#  'win lose bt': 2446,
#  'lose bt fightng': 1186,
#  'bt fightng close': 84,
#  'fightng close dificult': 606,
#  'close dificult lose': 289,
#  'dificult lose lose': 508,
#  'lose lose win': 1187,
#  'lose win still': 1189,
#  'win still lose': 2450,
#  'congratul week competit': 381,
#  'competit draw prize': 361,
#  'prize claim call': 1583,
#  'claim call cs': 263,
#  'call cs stop': 92,
#  'cs stop sm': 443,
#  'stop sm ppm': 2028,
#  'opinion jada kusruthi': 1413,
#  'jada kusruthi lovabl': 1048,
#  'kusruthi lovabl silent': 1117,
#  'lovabl silent spl': 1191,
#  'silent spl charact': 1877,
#  'spl charact matur': 1986,
#  'charact matur stylish': 230,
#  'matur stylish simpl': 1247,
#  'stylish simpl pl': 2035,
#  'simpl pl repli': 1881,
#  'prabha soryda reali': 1575,
#  'soryda reali frm': 1966,
#  'reali frm heart': 1610,
#  'frm heart sori': 718,
#  'guarante latest nokia': 933,
#  'latest nokia phone': 1154,
#  'nokia phone gb': 1367,
#  'phone gb ipod': 1504,
#  'gb ipod mp': 753,
#  'ipod mp player': 1035,
#  'mp player prize': 1308,
#  'player prize txt': 1523,
#  'prize txt word': 1588,
#  'txt word collect': 2252,
#  'word collect ibhltd': 2467,
#  'collect ibhltd ldnw': 314,
#  'ibhltd ldnw mtmsgrcvd': 996,
#  'free need know': 679,
#  'shall come get': 1849,
#  'come get pickl': 343,
#  'caller prize nd': 155,
#  'prize nd attempt': 1587,
#  'nd attempt contact': 1335,
#  'attempt contact call': 38,
#  'contact call box': 384,
#  'call box qu': 90,
#  'today offer claim': 2129,
#  'claim ur worth': 280,
#  'ur worth discount': 2349,
#  'worth discount voucher': 2476,
#  'discount voucher text': 510,
#  'voucher text ye': 2398,
#  'text ye savamob': 2074,
#  'ye savamob member': 2495,
#  'savamob member offer': 1738,
#  'member offer mobil': 1257,
#  'offer mobil cs': 1380,
#  'mobil cs sub': 1287,
#  'cs sub unsub': 444,
#  'statement show un': 2016,
#  'show un redeem': 1870,
#  'un redeem point': 2274,
#  'redeem point call': 1628,
#  'point call identifi': 1559,
#  'today sunday sunday': 2132,
#  'sunday sunday holiday': 2039,
#  'sunday holiday work': 2038,
#  'good afternoon love': 854,
#  'afternoon love goe': 8,
#  'love goe day': 1195,
#  'passion kiss across': 1453,
#  'kiss across sea': 1089,
#  'ummmmmaah mani mani': 2273,
#  'mani mani happi': 1239,
#  'mani happi return': 1238,
#  'happi return day': 951,
#  'return day dear': 1676,
#  'day dear sweet': 466,
#  'dear sweet heart': 484,
#  'sweet heart happi': 2044,
#  'heart happi birthday': 957,
#  'happi birthday dear': 947,
#  'stop txt stop': 2030,
#  'sorri took long': 1964,
#  'fuck babe miss': 726,
#  'cash prize claim': 207,
#  'new video phone': 1352,
#  'ur chanc win': 2306,
#  'chanc win wkli': 228,
#  'shop spree txt': 1861,
#  'spree txt shop': 1992,
#  'txt shop www': 2247,
#  'shop www txt': 1863,
#  'txt shop com': 2246,
#  'shop com custcar': 1857,
#  'com custcar wk': 328,
#  'close cost ppm': 288,
#  'cost ppm cs': 410,
#  'cs appli ag': 436,
#  'import custom servic': 1004,
#  'custom servic announc': 454,
#  'servic announc call': 1827,
#  'cant wait see': 178,
#  'latest news result': 1153,
#  'news result daili': 1355,
#  'game send di': 741,
#  'send di msg': 1795,
#  'ur friend answer': 2312,
#  'friend answer someon': 704,
#  'someon realli love': 1944,
#  'colour suit best': 327,
#  'well take care': 2428,
#  'happi valentin day': 952,
#  'got lt gt': 875,
#  'got thing may': 882,
#  'textbuddi chat horni': 2075,
#  'chat horni guy': 240,
#  'ur area free': 2297,
#  'free receiv search': 683,
#  'receiv search postcod': 1620,
#  'search postcod gaytextbuddi': 1761,
#  'gaytextbuddi com txt': 751,
#  'com txt one': 336,
#  'txt one name': 2237,
#  'today vodafon number': 2137,
#  'vodafon number end': 2389,
#  'receiv award number': 1614,
#  'award number match': 52,
#  'call receiv award': 131,
#  'hi hi hi': 966,
#  'dear voucher holder': 486,
#  'voucher holder claim': 2397,
#  'holder claim week': 975,
#  'claim week offer': 282,
#  'week offer pc': 2420,
#  'go http www': 828,
#  'http www tlp': 992,
#  'www tlp co': 2488,
#  'tlp co uk': 2117,
#  'co uk expressoff': 296,
#  'uk expressoff ts': 2261,
#  'expressoff ts cs': 573,
#  'ts cs appli': 2203,
#  'cs appli stop': 437,
#  'text txt stop': 2071,
#  'askd question hour': 36,
#  'question hour answer': 1594,
#  'watch cartoon listen': 2410,
#  'cartoon listen music': 192,
#  'listen music amp': 1175,
#  'music amp eve': 1324,
#  'amp eve go': 11,
#  'eve go templ': 548,
#  'go templ amp': 837,
#  'templ amp church': 2057,
#  'rstm sw ss': 1709,
#  'sea lay rock': 1757,
#  'lay rock rock': 1160,
#  'rock rock envelop': 1700,
#  'rock envelop envelop': 1699,
#  'paper paper word': 1441,
#  'go home first': 826,
#  'good even ttyl': 858,
#  'gt way could': 924,
#  'finish work yet': 628,
#  'pleas call immedi': 1527,
#  'call immedi urgent': 99,
#  'immedi urgent messag': 1003,
#  'urgent messag wait': 2355,
#  'confid aeronaut professor': 372,
#  'calld amp wer': 152,
#  'sit aeroplan aftr': 1894,
#  'sat wer told': 1732,
#  'told dat plane': 2139,
#  'said made student': 1725,
#  'start datz confid': 2006,
#  'know lunch menu': 1101,
#  'urgent nd attempt': 2359,
#  'contact call csbcm': 385,
#  'call csbcm wc': 93,
#  'csbcm wc xx': 448,
#  'wc xx callcost': 2416,
#  'callcost ppm mobilesvari': 151,
#  'prize claim yr': 1585,
#  'claim yr prize': 284,
#  'yr prize call': 2498,
#  'prize call custom': 1582,
#  'custom loyalti offer': 451,
#  'loyalti offer new': 1199,
#  'offer new nokia': 1381,
#  'new nokia mobil': 1350,
#  'nokia mobil txtauction': 1366,
#  'mobil txtauction txt': 1295,
#  'txtauction txt word': 2255,
#  'txt word start': 2254,
#  'word start get': 2469,
#  'start get ctxt': 2007,
#  'get ctxt tc': 766,
#  'ctxt tc mtmsg': 449,
#  'take good care': 2047,
#  'content servic uk': 397,
#  'servic uk per': 1838,
#  'send stop helplin': 1808,
#  'servic announc premier': 1828,
#  'call ts cs': 144,
#  'wish famili merri': 2457,
#  'famili merri ma': 582,
#  'merri ma happi': 1258,
#  'ma happi new': 1226,
#  'happi new year': 950,
#  'new year advanc': 1354,
#  'ur award citi': 2300,
#  'award citi break': 49,
#  'citi break could': 261,
#  'break could win': 81,
#  'could win summer': 416,
#  'win summer shop': 2451,
#  'summer shop spree': 2037,
#  'shop spree everi': 1860,
#  'spree everi wk': 1991,
#  'everi wk txt': 557,
#  'wk txt store': 2462,
#  'txt store skilgm': 2249,
#  'store skilgm tsc': 2031,
#  'skilgm tsc winawk': 1900,
#  'tsc winawk age': 2206,
#  'winawk age perwksub': 2454,
#  'lt gt minut': 1211,
#  'txt back name': 2218,
#  'call nation rate': 119,
#  'ok msg leav': 1394,
#  'last chanc claim': 1137,
#  'chanc claim ur': 220,
#  'discount voucher today': 511,
#  'voucher today text': 2399,
#  'today text shop': 2133,
#  'shop savamob offer': 1859,
#  'savamob offer mobil': 1739,
#  'mobil cs savamob': 1286,
#  'cs savamob pobox': 442,
#  'savamob pobox uz': 1740,
#  'pobox uz sub': 1555,
#  'lt time gt': 1218,
#  'free st week': 689,
#  'st week nokia': 2002,
#  'week nokia tone': 2419,
#  'nokia tone ur': 1369,
#  'tone ur mobil': 2164,
#  'ur mobil everi': 2334,
#  'mobil everi week': 1288,
#  'everi week txt': 555,
#  'week txt nokia': 2422,
#  'txt nokia get': 2236,
#  'nokia get txting': 1363,
#  'get txting tell': 786,
#  'txting tell ur': 2257,
#  'tell ur mate': 2054,
#  'ur mate www': 2329,
#  'mate www getz': 1245,
#  'www getz co': 2482,
#  'getz co uk': 791,
#  'co uk pobox': 299,
#  'uk pobox wq': 2269,
#  'pobox wq norm': 1556,
#  'wq norm tone': 2477,
#  'guarante award even': 927,
#  'cashto claim ur': 211,
#  'claim ur award': 278,
#  'ur award call': 2298,
#  'award call free': 47,
#  'free stop getstop': 690,
#  'ur award either': 2302,
#  'award either cd': 50,
#  'either cd gift': 534,
#  'cd gift voucher': 214,
#  'gift voucher free': 799,
#  'voucher free entri': 2395,
#  'entri weekli draw': 545,
#  'weekli draw txt': 2426,
#  'ok take care': 1398,
#  'text credit pl': 2067,
#  'credit pl goto': 430,
#  'pl goto www': 1515,
#  'goto www comuk': 884,
#  'www comuk net': 2481,
#  'comuk net login': 369,
#  'net login qxj': 1342,
#  'login qxj unsubscrib': 1181,
#  'qxj unsubscrib stop': 1598,
#  'unsubscrib stop extra': 2288,
#  'stop extra charg': 2026,
#  'extra charg help': 574,
#  'charg help comuk': 232,
#  'help comuk cm': 963,
#  'comuk cm ae': 368,
#  'alfi moon children': 10,
#  'moon children need': 1302,
#  'children need song': 254,
#  'need song ur': 1340,
#  'song ur mob': 1951,
#  'ur mob tell': 2333,
#  'mob tell ur': 1283,
#  'tell ur txt': 2055,
#  'ur txt tone': 2346,
#  'txt tone chariti': 2250,
#  'tone chariti nokia': 2149,
#  'chariti nokia poli': 236,
#  'nokia poli chariti': 1368,
#  'poli chariti poli': 1561,
#  'chariti poli zed': 237,
#  'poli zed profit': 1563,
#  'zed profit chariti': 2499,
#  'hahaha use brain': 941,
#  'use brain dear': 2372,
#  'secret admir reveal': 1764,
#  'reveal think special': 1680,
#  'special call opt': 1973,
#  'call opt repli': 122,
#  'opt repli reveal': 1414,
#  'repli reveal stop': 1660,
#  'reveal stop per': 1679,
#  'per msg recd': 1477,
#  'recd cust care': 1611,
#  'offer pc pleas': 1382,
#  'pc pleas go': 1461,
#  'pleas go http': 1530,
#  'skype wit kz': 1904,
#  'kz sura didnt': 1118,
#  'get pleasur compani': 783,
#  'compani hope good': 359,
#  'hope good given': 985,
#  'good given ultimatum': 860,
#  'given ultimatum oh': 816,
#  'ultimatum oh countin': 2272,
#  'oh countin aburo': 1385,
#  'countin aburo enjoy': 417,
#  'good morn dear': 861,
#  'dear great amp': 476,
#  'great amp success': 892,
#  'amp success day': 17,
#  'network min text': 1344,
#  'phone five pound': 1501,
#  'five pound per': 634,
#  'pound per week': 1572,
#  'per week call': 1481,
#  'week call repli': 2417,
#  'call repli deliveri': 132,
#  'repli deliveri tomorrow': 1652,
#  'late pay rent': 1145,
#  'pay rent past': 1459,
#  ...}
